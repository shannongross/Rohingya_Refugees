# %%
import pandas as pd
import geopandas as gpd 
import numpy as np
import matplotlib.pyplot as plt
import mplleaflet

# %matplotlib inline

# %% [markdown]
# ### Get shapefiles

# %%
# Data from: https://data.humdata.org/dataset/outline-of-camps-sites-of-rohingya-refugees-in-cox-s-bazar-bangladesh
# Download and unzip, replace path location below

path = r'C:\Users\shann\Documents\3 Projects\3.4 Rohingya\3.4.2 Notebooks\data'
gpdf = gpd.read_file(path+'\\180528_Outline_Rohingya_Refugee_Camp_A1.shp')
gpdf.head()
# Out:
#       New_Camp_N     District Upazila       Settlement         Union  \
# 0        Camp 16  Cox's Bazar   Ukhia  Collective site  Palong Khali
# 1        Camp 2E  Cox's Bazar   Ukhia  Collective site  Palong Khali
# 2         Camp 7  Cox's Bazar   Ukhia  Collective site  Palong Khali
# 3        Camp 15  Cox's Bazar   Ukhia  Collective site  Palong Khali
# 4  Kutupalong RC  Cox's Bazar   Ukhia  Collective site   Raja Palong
#
#            Name_Alias     SSID  \
# 0  Bagghona-Putibonia  CXB-224
# 1                None  CXB-203
# 2              Gundum  CXB-207
# 3     Jamtoli-Baggona  CXB-223
# 4       Kutupalong RC  CXB-221
#
#                                             geometry
# 0  POLYGON ((92.15055569948601 21.16119109439353,...
# 1  POLYGON ((92.16602099177538 21.20869839931174,...
# 2  POLYGON ((92.16046234516114 21.20432814203019,...
# 3  POLYGON ((92.13912528660273 21.1649860823419, ...
# 4  POLYGON ((92.16545507089484 21.21481206882197,...

# %% [markdown]
# ### Create camp figure

# %%
f, ax = plt.subplots(1, figsize=(12, 12))
ax = gpdf.plot(ax=ax, color='red',edgecolors='black')
mplleaflet.display(fig=f)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="720"></iframe>
